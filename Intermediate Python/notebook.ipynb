# %% [markdown]
# # Intermediate Python
# Run the hidden code cell below to import the data used in this course.

# %%
# Import the course packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import the two datasets
gapminder = pd.read_csv("datasets/gapminder.csv")
brics = pd.read_csv("datasets/brics.csv")

# %% [markdown]
# ## PART ONE

# %% [markdown]
# ## 1 Basic plots with Matplotlib
#
# ![Screen Shot 2023-09-07 at 3.22.03 PM](Screen%20Shot%202023-09-07%20at%203.22.03%20PM.png)
#
# ## Data visualization
# - Very important in Data Analysis
#     - Explore data
#     - Report insights
#
# ![Screen Shot 2023-09-07 at 3.25.30 PM](Screen%20Shot%202023-09-07%20at%203.25.30%20PM.png)
#
#
#
# ![Screen Shot 2023-09-07 at 3.26.26 PM](Screen%20Shot%202023-09-07%20at%203.26.26%20PM.png)
#
# ## Matplotlib
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1970, 1990, 2010]
# pop = [2.519, 3.692, 5.263, 6.972]
# plt.plot(year, pop)
# plt.show()
# ```
#
# ## Scatter plot
#
# ```python
# plt.scatter(year, pop)
# plt.show()
# ```

# %%
# Add your code snippets here
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]
plt.plot(year, pop)
plt.show()

# %%
plt.scatter(year, pop)
plt.show()

# %% [markdown]
# ## 2 Histogram
#
# - Explore dataset
# - Get idea about distribution
#
# ![Screen Shot 2023-09-07 at 3.30.55 PM](Screen%20Shot%202023-09-07%20at%203.30.55%20PM.png)
#
# ## Matplotlib Example
#
# ```python
# import matplotlib.pyplot as plt
# values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
# plt.hist(values, bins=3)
# plt.show()
# ```
#
# ## Population pyramid
#
#
# ![Screen Shot 2023-09-07 at 3.33.10 PM](Screen%20Shot%202023-09-07%20at%203.33.10%20PM.png)

# %% [markdown]
# ## 3 Customization
#
# ### Data visualization
# - Many options
#     - Different plot types
#     - Many customizations
# - Choice depends on
#     - Data
#     - Story you want to tell
#
# ## Basic plot
# ```python
# population.py
# ```
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1951, 1952, ..., 2100]
# pop = [2.538, 2.57, 2.62, ..., 10.85]
# plt.plot(year, pop)
# plt.show()
# ```
#
# ![Screen Shot 2023-09-07 at 3.36.15 PM](Screen%20Shot%202023-09-07%20at%203.36.15%20PM.png)
#
# ## Axis labels
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1951, 1952, ..., 2100]
# pop = [2.538, 2.57, 2.62, ..., 10.85]
# plt.plot(year, pop)
# plt.xlabel('Year')
# plt.ylabel('Population')
# plt.show()
# ```
#
# ![Screen Shot 2023-09-07 at 3.39.54 PM](Screen%20Shot%202023-09-07%20at%203.39.54%20PM.png)
#
# ## Title
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1951, 1952, ..., 2100]
# pop = [2.538, 2.57, 2.62, ..., 10.85]
# plt.plot(year, pop)
# plt.xlabel('Year')
# plt.ylabel('Population')
# plt.title('World Population Projections')
# plt.show()
# ```
#
# ![Screen Shot 2023-09-07 at 3.41.07 PM](Screen%20Shot%202023-09-07%20at%203.41.07%20PM.png)
#
# ## Ticks
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1951, 1952, ..., 2100]
# pop = [2.538, 2.57, 2.62, ..., 10.85]
# plt.plot(year, pop)
# plt.xlabel('Year')
# plt.ylabel('Population')
# plt.title('World Population Projections')
# plt.show()
# plt.yticks([0, 2, 4, 6, 8, 10])
# ```
# ![Screen Shot 2023-09-07 at 3.42.10 PM](Screen%20Shot%202023-09-07%20at%203.42.10%20PM.png)
#
# ## Ticks (2)
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1951, 1952, ..., 2100]
# pop = [2.538, 2.57, 2.62, ..., 10.85]
# plt.plot(year, pop)
# plt.xlabel('Year')
# plt.ylabel('Population')
# plt.title('World Population Projections')
# plt.show()
# plt.yticks([0, 2, 4, 6, 8, 10],
#            ['0', '2B', '4B', '6B', '8B', '10B'])
# ```
#
# ![Screen Shot 2023-09-07 at 3.43.44 PM](Screen%20Shot%202023-09-07%20at%203.43.44%20PM.png)
#
# ## Add historical data
#
# ```python
# import matplotlib.pyplot as plt
# year = [1950, 1951, 1952, ..., 2100]
# pop = [2.538, 2.57, 2.62, ..., 10.85]
# # Add more data
# year = [1800, 1850, 1900] + year
# pop = [1.0, 1.262, 1.650] + pop
# plt.plot(year, pop)
# plt.xlabel('Year')
# plt.ylabel('Population')
# plt.title('World Population Projections')
# plt.show()
# plt.yticks([0, 2, 4, 6, 8, 10],
#            ['0', '2B', '4B', '6B', '8B', '10B'])
# ```
#
# ![Screen Shot 2023-09-07 at 3.45.25 PM](Screen%20Shot%202023-09-07%20at%203.45.25%20PM.png)
#
# ## Before vs. after
#
# ![Screen Shot 2023-09-07 at 3.45.36 PM](Screen%20Shot%202023-09-07%20at%203.45.36%20PM.png)

# %% [markdown]
# ## PART TWO

# %% [markdown]
# ## 1 Dictionaries, Part 1
#
# ### List
#
# ```python
# pop = [30.55, 2.77, 39.21]
# countries = ["afghanistan", "albania", "algeria"]
# ind_alb = countries.index("albania")
# ind_alb
# ```
#
# ```python
# pop[ind_alb]
# ```
# - Not convenient
# - Not intuitive
#
# ## Dictionary
#
# ```python
# pop = [30.55, 2.77, 39.21]
# countries = ["afghanistan", "albania", "algeria"]
# ...
#
# world = {"afghanistan":30.55, "albania":2.77, "algeria":39.21}
# world["albania"]
# ```

# %% [markdown]
# ## 2 Dictionaries, Part 2
#
# ### Recap
#
# ```python
# world = {"afghanistan":30.55, "albania":2.77, "algeria":39.21}
# world["albania"]
# ```
#
# ```python
# world = {"afghanistan":30.55, "albania":2.77,
#          "algeria":39.21, "albania":2.81}
# world
# ```
# - Keys have to be "immutable" objects
#
#
# ```python
# {0:"hello", True:"dear", "two":"world"}
# ```
#
# ```python
# {["just", "to", "test"]: "value"}
# ```
#
# ## Dictionary
#
# ```python
# world["sealand"] = 0.000027
# world
# ```
#
# ```python
# "sealand"in world
# ```
#
# ```python
# world["sealand"] = 0.000028
# world
# ```
#
# ```python
# del(world["sealand"])
# world
# ```
#
# ## List vs. Dictionary
#
# |```List ``` |```Dictionary```|
# |---   |----------|
# |Select, update, and removewith `[]`  |Select, update, and removewith `[]`|
# |```Indexed by range of numbers```  |```Indexed by unique keys```|
# Collection of values — order matters,for selecting entire subsets  |Lookup table withunique keys|

# %% [markdown]
# ## 3 Pandas, Part 1
#
# ### Tabular dataset examples
#
# ![Screen Shot 2023-09-07 at 4.03.26 PM](Screen%20Shot%202023-09-07%20at%204.03.26%20PM.png)
#
#
# ## Datasets in Python
# - 2D NumPy array?
#     - One data type
#
# - pandas!
#     - High level data manipulation tool
#     - Wes McKinney
#     - Built on NumPy
#     - DataFrame
#
# ## DataFrame
#
#
#  |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |IN         |India  |New Delhi   |3.286     |1252.00|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#  |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
# ## DataFrame from Dictionary
#
# ```python
# dict = { "country":["Brazil", "Russia", "India", "China", "South Africa"],
#         "capital":["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
#         "area":[8.516, 17.10, 3.286, 9.597, 1.221]"population":[200.4, 143.5, 1252, 1357, 52.98] }
# import pandas as pd
# brics = pd.DataFrame(dict)
# ```
# - keys (column labels)
# - values (data, column by column)
#
# ```python
# brics
# ```
#
#
#  |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |0        |Brazil   |Brasilia   |8.516      |200.40|
#  |1        |Russia     |Moscow  |17.100      |143.50|
#  |2         |India  |New Delhi   |3.286     |1252.00|
#  |3         |China    |Beijing   |9.597     |1357.00|
#  |4   |Pretoria   |1.221       |52.98|
#
#  ```python
#  brics.index = ["BR", "RU", "IN", "CH", "SA"]
#  brics
#  ```
#
#   |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |IN         |India  |New Delhi   |3.286     |1252.00|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#  |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
# ## DataFrame from CSV file
#
# ```python
# brics.csv
# ```
#
# ```python
# ,country,capital,area,population
# BR,Brazil,Brasilia,8.516,200.4
# RU,Russia,Moscow,17.10,143.5
# IN,India,New Delhi,3.286,1252
# CH,China,Beijing,9.597,1357
# SA,South Africa,Pretoria,1.221,52.98
# ```
#
# - CSV = comma-separated values
#
# ```python
# brics = pd.read_csv("path/to/brics.csv")
# brics
# ```
#
# |  |Unnamed: 0       |country    |capital    |area  |population|
# |--  |--------   |-------   |------- |----  |------|
# |0        |BR        |Brazil   |Brasilia   |8.516      |200.40|
# |1         |RU        |Russia     |Moscow  |17.100      |143.50|
# |2         |IN         |India  |New Delhi   |3.286     |1252.00|
# |3         |CH         |China    |Beijing   |9.597     |1357.00|
# |4         |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
# ```python
# brics = pd.read_csv("path/to/brics.csv", index_col = 0)
# brics
# ```
#
#
#   |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |IN         |India  |New Delhi   |3.286     |1252.00|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#  |SA  |South Africa   |Pretoria   |1.221       |52.98|

# %% [markdown]
# ## 3 Pandas, Part 2
#
# ```python
# import pandas as pd
# brics = pd.read_csv("path/to/brics.csv", index_col = 0)
# brics
# ```
#
#  |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |IN         |India  |New Delhi   |3.286     |1252.00|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#  |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
#  ## Index and select data
#
# - Square brackets
# - Advanced methods
#     - loc
#     - iloc
#
# ## Column Access `[ ]`
#
#
# ```python
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98
# ```
#
# ```python
# brics["country"]
# ```
# |    |   |
# |--  |---|
# |BR  |Brazil|
# |RU  |Russia|
# |IN  |India|
# |CH  |China|
# |SA  |South Africa|
# |Name: country, dtype: object
#
#
# ```python
# type(brics["country"])
# ```
#
# ```python
# brics[["country"]]
# ```
#
# |    |   |
# |--  |---|
# |BR  |Brazil|
# |RU  |Russia|
# |IN  |India|
# |CH  |China|
# |SA  |South Africa|
#
# ```python
# type(brics[["country"]])
# ```
#
# ```python
# brics[["country", "capital"]]
# ```
#
# |    |country |capital|
# |--  |--- |----|
# |BR  |Brazil  |Brasilia|
# |RU  |Russia  |Moscow|
# |IN  |India  |New Delhi|
# |CH  |China  |Beijing|
# |SA  |South Africa  | Pretoria|
#
# ## Row Access [ ]
#
# ```python
# brics[1:4]
# ```
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
# |IN         |India  |New Delhi   |3.286     |1252.00|
# |CH         |China    |Beijing   |9.597     |1357.00|
# |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
#
# ## Discussion [ ]
# - Square brackets: limited functionality
# - Ideally
#     - 2D NumPy arrays
#     - my_array[rows, columns]
# - pandas
#     - loc (label-based)
#     - iloc (integer position-based)
#
# ## Row Access loc
#
# ```python
# brics.loc["RU"]
# ```
#
# |         |        |
# |------   |--------|
# |country       |Russia|
# |capital       |Moscow|
# |area            |17.1|
# |population     |143.5|
# |Name: RU, dtype: object
#
# - Row as pandas Series
#
# ```python
# brics.loc[["RU"]]
# ```
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
# - DataFrame
# ```python
# brics.loc[["RU", "IN", "CH"]]
# ```
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
# |IN         |India  |New Delhi   |3.286     |1252.00|
# |CH         |China    |Beijing   |9.597     |1357.00|
#
# ## Row & Column loc
#
# ```python
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98
# ```
#
# ```python
# brics.loc[["RU", "IN", "CH"], ["country", "capital"]]
# ```
#
# |  |country    |capital|
# |-- |------  |--------|
# |RU  |Russia     |Moscow|
# |IN   |India  |New Delhi|
# |CH   |China    |Beijing|
#
# ```python
# brics.loc[:, ["country", "capital"]]
# ```
#
# |  |country    |capital|
# |-- |------  |--------|
# |BR  |Brazil   |Brasilia|
# |RU  |Russia     |Moscow|
# |IN   |India  |New Delhi|
# |CH   |China    |Beijing|
# |SA  |South Africa   |Pretoria|
#
#
# ## Recap
# - Square brackets
#     - Column access ```brics[["country", "capital"]]```
#     - Row access: only through slicing ```brics[1:4]```
# - loc (label-based)
#     - Row access ```brics.loc[["RU", "IN", "CH"]]```
#     - Column access ```brics.loc[:, ["country", "capital"]]```
#     - Row & Column access
#     ```python
#     brics.loc[
#     ["RU", "IN", "CH"],
#     ["country", "capital"]
#     ]
#     ```
#
#
# ## Row Access iloc
#
#
# ```python
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98
# ```
#
# ```python
# brics.loc[["RU"]]
# ```
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
#
# ```python
# brics.iloc[[1]]
# ```
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
#
# ```python
# brics.loc[["RU", "IN", "CH"]]
# ```
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
# |IN         |India  |New Delhi   |3.286     |1252.00|
# |CH         |China    |Beijing   |9.597     |1357.00|
#
# ```python
# brics.iloc[[1,2,3]]
# ```
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |RU        |Russia     |Moscow  |17.100      |143.50|
# |IN         |India  |New Delhi   |3.286     |1252.00|
# |CH         |China    |Beijing   |9.597     |1357.00|
#
# ```python
# brics.loc[["RU", "IN", "CH"], ["country", "capital"]]
# ```
#
# |        |country    |capital    |
# |----  |-------  |------  |
# |RU        |Russia     |Moscow  |
# |IN         |India  |New Delhi   |
# |CH         |China    |Beijing   |
#
# ```python
# brics.iloc[[1,2,3], [0, 1]]
# ```
#
# |        |country    |capital    |
# |----  |-------  |------  |
# |RU        |Russia     |Moscow  |
# |IN         |India  |New Delhi   |
# |CH         |China    |Beijing   |
#
#
# ```python
# brics.loc[:, ["country", "capital"]]
# ```
#
# |  |country    |capital|
# |-- |------  |--------|
# |BR  |Brazil   |Brasilia|
# |RU  |Russia     |Moscow|
# |IN   |India  |New Delhi|
# |CH   |China    |Beijing|
# |SA  |South Africa   |Pretoria|
#
#
# ```python
# brics.iloc[:, [0,1]]
# ```
# |  |country    |capital|
# |-- |------  |--------|
# |BR  |Brazil   |Brasilia|
# |RU  |Russia     |Moscow|
# |IN   |India  |New Delhi|
# |CH   |China    |Beijing|
# |SA  |South Africa   |Pretoria|

# %% [markdown]
# # PART THREE

# %% [markdown]
# ## 1 Comparison Operators
#
# ### NumPy recap
#
# ```python
# # Code from Intro to Python for Data Science, Chapter 4
# import numpy as np
# np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
# np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])
# bmi = np_weight / np_height ** 2
# bmi
# ```
#
# ```python
# bmi > 23
# ```
#
#
# ```python
# bmi[bmi > 23]
# ```
# - Comparison operators: how Python values relate
#
# ## Numeric comparisons
#
#
# ```python
# 2 < 3
# ```
# ```python
# 2 == 3
# ```
#
# ```python
# 2 <= 3
# ```
#
# ```python
# 3 <= 3
# ```
#
# ```python
# x = 2
# y = 3
# x < y
# ```
#
# ## Other comparisons
#
# ```python
# "carl" < "chris"
# ```
#
# ```python
# 3 < "chris"
# ```
#
# ```python
# 3 < 4.1
# ```
#
# ```python
# bmi > 23
# ```
#
#
# ## Comparators
#
# |Comparator |Meaning|
# |------     |------|
# |<   |Strictly less than|
# |<=  |Less than or equal|
# |>   |Strictly greater than|
# |>=  |Greater than or equal|
# |==  |Equal|
# |!=  |Not equal|

# %% [markdown]
# ## Boolean Operators
#
# **Boolean Operators**
# - and
# - or
# - not
#
# ## and
#
# ```python
# True and True
# ```
#
# ```python
# x = 12
# x > 5 and x < 15
# # True     True
# ```
#
# ```python
# False and True
# ```
#
# ```python
# True and False
# ```
#
# ```python
# False and False
# ```
#
#
#
# ## or
#
# ```python
# True or True
# ```
#
# ```python
# False or True
# ```
#
# ```python
# True or False
# ```
#
#
# ```python
# False or False
# ```
#
# ```python
# y = 5
# y < 7 or y > 13
# ```
#
# ## not
#
#
# ```python
# not True
# ```
#
#
# ```python
# not False
# ```
#
# ## NumPy
#
#
#
# ```python
# bmi     # calculation of bmi left out
# ```
#
#
# ```python
# bmi > 21
# ```
#
#
# ```python
# bmi < 22
# ```
#
#
# ```python
# bmi > 21and bmi < 22
# ```
#
# ## NumPy
#
# - `logical_and()`
# - `logical_or()`
# - `logical_not()`
#
# ```python
# np.logical_and(bmi > 21, bmi < 22)
# ```
#
# ```python
# bmi[np.logical_and(bmi > 21, bmi < 22)]
# ```

# %% [markdown]
# ## if, elif, else
#
#
# ### Overview
#
# - Comparison
#     - ```Operators<, >, >=, <=, ==, !=```
# - Boolean Operators
#     - ```and, or, not```
# - Conditional Statements
#     - ```if, else, elif```
#
# ## if
#
# ```python
# if condition :
#     expression
# ```
#
# ```python
# control.py
# ```
#
# ```python
# z = 4
# if z % 2 == 0 :    # True
#     print("z is even")
# ```
#
# ## if
#
#
# ```python
# if condition :
#     expression
# ```
# - `expression` not part of if
#
# ```python
# control.py
# ```
#
# ```python
# z = 4
# if z % 2 == 0 :    # True
#     print("z is even")
# ```
#
# ## if
#
# ```python
# if condition :
#     expression
# ```
#
#
# ```python
# control.py
# ```
#
# ```python
# z = 4
# if z % 2 == 0 :
#     print("checking "  + str(z))
#     print("z is even")
# ```
#
#
# ## if
#
# ```python
# if condition :
#     expression
# ```
#
#
# ```python
# control.py
# ```
#
# ```python
# z = 5
# if z % 2 == 0 :    # False
#     print("checking "  + str(z))
#     print("z is even")
# ```
#
# ## else
#
# ```python
# if condition :
#     expression
# else :    expression
# ```
#
#
# ```python
# control.py
# ```
#
# ```python
# z = 5
# if z % 2 == 0 :    # False
#     print("z is even")
# else :
#     print("z is odd")
# ```
#
# ## elif
#
# ```python
# if condition :
#     expression
# elif condition :
#     expression
# else :
#     expression
# ```
#
# ```control.py```
#
# ```python
# z = 3
# if z % 2 == 0 :
#     print("z is divisible by 2")    # False
# elif z % 3 == 0 :
#     print("z is divisible by 3")    # True
# else :
#     print("z is neither divisible by 2 nor by 3")
# ```
#
# ```python
# z = 6
# if z % 2 == 0 :
#     print("z is divisible by 2")    # True
# elif z % 3 == 0 :
#     print("z is divisible by 3")    # Never reached
# else :
#     print("z is neither divisible by 2 nor by 3")
# ```
#
# ## Filtering pandas DataFrames
#
# ```python
#
# import pandas as pd
# brics = pd.read_csv("path/to/brics.csv", index_col = 0)
# brics
# ```
#
# |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |IN         |India  |New Delhi   |3.286     |1252.00|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#  |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
#  ## Goal
#
#  - Select countries with area over 8 million km2
#  - 3 steps
#      - Select the area column
#      - Do comparison on area column
#      - Use result to select countries
#
# ### Step 1: Get column
#
# ```python
# brics["area"]
# ```
# |  |   |
# |-- |--- |
# |BR     |8.516|
# |RU    |17.100|
# |IN     |3.286|
# |CH     |9.597|
# |SA     |1.221|
# |Name: area, dtype: float64    # - Need Pandas Series
#
# - Alternatives:
#
# ```python
# brics.loc[:,"area"]
# brics.iloc[:,2]
# ```
#
# ### Step 2: Compare
#
# ```python
# brics["area"] > 8
# ```
# |  |   |
# |-- |--- |
# |BR     |True|
# |RU    |True|
# |IN     |False|
# |CH     |True|
# |SA     |False|
# |Name: area, dtype: bool
#
# ```python
# is_huge = brics["area"] > 8
# ```
#
# ### Step 3: Subset DF
#
# ```python
# is_huge
# ```
# |  |   |
# |-- |--- |
# |BR     |True|
# |RU    |True|
# |IN     |False|
# |CH     |True|
# |SA     |False|
# |Name: area, dtype: bool
#
# ```python
# brics[is_huge]
# ```
#
# |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#
# ## Summary
#
# |        |country    |capital    |area  |population|
# |----  |-------  |------  |------  |-----|
# |BR        |Brazil   |Brasilia   |8.516      |200.40|
# |RU        |Russia     |Moscow  |17.100      |143.50|
# |IN         |India  |New Delhi   |3.286     |1252.00|
# |CH         |China    |Beijing   |9.597     |1357.00|
# |SA  |South Africa   |Pretoria   |1.221       |52.98|
#
#
# ```python
# is_huge = brics["area"] > 8
# brics[is_huge]
# ```
#
# |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#
# ```python
# brics[brics["area"] > 8]
# ```
#
# |        |country    |capital    |area  |population|
#  |----  |-------  |------  |------  |-----|
#  |BR        |Brazil   |Brasilia   |8.516      |200.40|
#  |RU        |Russia     |Moscow  |17.100      |143.50|
#  |CH         |China    |Beijing   |9.597     |1357.00|
#
# ## Boolean operators
#
# ```python
# import numpy as np
# np.logical_and(brics["area"] > 8, brics["area"] < 10)
# ```
#
# ```python
# brics[np.logical_and(brics["area"] > 8, brics["area"] < 10)]
# ```

# %%
import pandas as pd
brics = pd.read_csv("datasets/brics.csv", index_col = 0)
brics
brics["area"]
# Alternatives

brics.loc[:,"area"]
brics.iloc[:,2]
brics["area"] > 8
is_huge = brics["area"] > 8
brics[is_huge]
## Boolean operator

import numpy as np
np.logical_and(brics["area"] > 8, brics["area"] < 10)
brics[np.logical_and(brics["area"] > 8, brics["area"] < 10)]
# Out:
#            country   capital   area  population
# country_ab
# BR          Brazil  Brasilia  8.516       200.4
# CH           China   Beijing  9.597      1357.0

# %% [markdown]
# # PART FOUR

# %% [markdown]
# ## 1 while loop
#
# ### if-elif-else
#
# ```control.py```
#
# - Goes through construct only once!
#
# ```python
# z = 6
# if z % 2 == 0 :  # True
#     print("z is divisible by 2")  # Executed
# elif z % 3 == 0 :
#     print("z is divisible by 3")
# else :
#     print("z is neither divisible by 2 nor by 3")
#
# ... # Moving on
# ```
# - While loop = repeated if statement
#
# ```python
# while condition :
#     expression
# ```
#
# - Numerically calculating model
# - "repeating action until condition is met
# - "Example
#     - Error starts at 50
#     - Divide error by 4 on every run
#     - Continue until error no longer > 1
#
#
# ```python
# while condition :
#     expression
# ```
#
# ```while_loop.py```
#
# ```python
# error = 50.0
# while error > 1:
#     error = error / 4
#     print(error)
# ```
#
# - Error starts at 50
# - Divide error by 4 on every run
# - Continue until error no longer > 1

# %% [markdown]
# ## for loop
#
#
# ```python
# for var in seq :
#     expression
# ```
# - "for each var in seq, execute expression"
#
# ### fam
#
# ```family.py```
#
# ```python
# fam = [1.73, 1.68, 1.71, 1.89]
# print(fam)
# print(fam[0])
# print(fam[1])
# print(fam[2])
# print(fam[3])
# ```
# ```python
# fam = [1.73, 1.68, 1.71, 1.89]
# for height in fam :
#     print(height)
#     # first iteration
#     # height = 1.73
#     # second iteration
#     # height = 1.68
# ```
#
# - No access to indexes
#
#
# ### enumerate
#
# ```python
# fam = [1.73, 1.68, 1.71, 1.89]
# for index, height in enumerate(fam) :
#     print("index " + str(index) + ": " + str(height))
# ```
#
# ### Loop over string
#
# ```python
# for c in "family" :
#     print(c.capitalize())
# ```

# %% [markdown]
# ## Loop Data Structures Part 1
#
# ### Dictionary
#
# ```python
# world = { "afghanistan":30.55,
#          "albania":2.77,
#          "algeria":39.21 }
# for key, value in world :
#     print(key + " -- " + str(value))
# ```
#
# ```python
# world = { "afghanistan":30.55,
#          "albania":2.77,
#          "algeria":39.21 }
# for key, value in world.items() :
#     print(key + " -- " + str(value))
# ```
#
# ```python
# world = { "afghanistan":30.55,
#          "albania":2.77,
#          "algeria":39.21 }
# for k, v in world.items() :
#     print(k + " -- " + str(v))
# ```
#
# ### NumPy Arrays
#
# ```python
# import numpy as np
# np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
# np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])
# bmi = np_weight / np_height ** 2
# for val in bmi :
#     print(val)
# ```
#
# ### 2D NumPy Arrays
#
# ```python
# import numpy as np
# np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
# np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])
# meas = np.array([np_height, np_weight])
# for val in meas :
#     print(val)
# ```
#
# ```python
# import numpy as np
# np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
# np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])
# meas = np.array([np_height, np_weight])
# for val in np.nditer(meas) :
#     print(val)
# ```
#
# ### Recap
# - Dictionary
#     - ```for key, val in my_dict.items() :```
# - NumPy array
#     - ```for val in np.nditer(my_array) :```

# %% [markdown]
# ## Loop Data Structures Part 2
#
# brics
#
# ```python
# country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98
# ```
#
# ```python
# import pandas as pd
# brics = pd.read_csv("brics.csv", index_col = 0)
# for val in brics :
#     print(val)
# ```
#
# ```python
# for lab, row in brics.iterrows():
#     print(lab)
#     print(row)
# ```
#
# ### Selective print
#
# ```python
# for lab, row in brics.iterrows():
#     print(lab + ": " + row["capital"])
# ```
#
# ```python
# for lab, row in brics.iterrows() :
#     # - Creating Series on every iteration
#     brics.loc[lab, "name_length"] = len(row["country"])
# print(brics)
# ```
#
# ### apply
#
# ```python
# brics["name_length"] = brics["country"].apply(len)
# print(brics)
# ```

# %%
for val in brics :
    print(val)
# Out:
# country
# capital
# area
# population

# %%
for lab, row in brics.iterrows():
    print(lab)
    print(row)
# Out:
# BR
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object
# RU
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
# IN
# country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: IN, dtype: object
# CH
# country         China
# capital       Beijing
# area            9.597
# population     1357.0
# Name: CH, dtype: object
# SA
# country       South Africa
# capital           Pretoria
# area                 1.221
# population           52.98
# Name: SA, dtype: object

# %%
for lab, row in brics.iterrows():
    print(lab + ": " + row["capital"])
# Out:
# BR: Brasilia
# RU: Moscow
# IN: New Delhi
# CH: Beijing
# SA: Pretoria

# %%
for lab, row in brics.iterrows() :
    # - Creating Series on every iteration    
    brics.loc[lab, "name_length"] = len(row["country"])
print(brics)
# Out:
#                  country    capital    area  population  name_length
# country_ab
# BR                Brazil   Brasilia   8.516      200.40          6.0
# RU                Russia     Moscow  17.100      143.50          6.0
# IN                 India  New Delhi   3.286     1252.00          5.0
# CH                 China    Beijing   9.597     1357.00          5.0
# SA          South Africa   Pretoria   1.221       52.98         12.0

# %%
brics["name_length"] = brics["country"].apply(len)
print(brics)
# Out:
#                  country    capital    area  population  name_length
# country_ab
# BR                Brazil   Brasilia   8.516      200.40            6
# RU                Russia     Moscow  17.100      143.50            6
# IN                 India  New Delhi   3.286     1252.00            5
# CH                 China    Beijing   9.597     1357.00            5
# SA          South Africa   Pretoria   1.221       52.98           12

# %% [markdown]
# ## PART FIVE

# %% [markdown]
# ## Random Numbers
#
# **Random generators**
#
# ```python
# import numpy as np
# np.random.rand()      # Pseudo-random numbers
# ```
#
# ```python
# np.random.seed(123)    # Starting from a seednp.random.rand()
# ```
#
# ```python
# np.random.rand()    # Ensures "reproducibility"
# ```
#
# ## Coin toss
#
# ```python
# np.random.seed(123)
# coin = np.random.randint(0,2)  # Randomly generate 0 or 1
# print(coin)
# ```
#
# ```python
# import numpy as np
# np.random.seed(123)
# coin = np.random.randint(0,2)  # Randomly generate 0 or 1
# print(coin)
# if coin == 0:
#     print("heads")
# else:
#     print("tails")
# ```

# %%
# Random Numbers

import numpy as np
np.random.rand()      # Pseudo-random numbers
np.random.seed(123)    # Starting from a seednp.random.rand()
np.random.rand()    # Ensures "reproducibility"
## Coin toss
np.random.seed(123)
coin = np.random.randint(0,2)  # Randomly generate 0 or 1
print(coin)
if coin == 0:
    print("heads")
else:
    print("tails")
# Out:
# 0
# heads

# %% [markdown]
# ## Random Walk
#
# **Heads or Tails**
#
# ```python
# import numpy as np
# np.random.seed(123)
# outcomes = []
# for x in range(10) :
#     coin = np.random.randint(0, 2)
#     if coin == 0 :
#         outcomes.append("heads")
#     else :
#         outcomes.append("tails")
# print(outcomes)
# ```
#
# ## Heads or Tails: Random Walk
#
# ```python
# import numpy as np
# np.random.seed(123)
# tails = [0]
# for x in range(10) :
#     coin = np.random.randint(0, 2)
#     tails.append(tails[x] + coin)
# print(tails)
# ```

# %% [markdown]
# ## Distribution
#
# **Random Walk**
#
# ```python
# import numpy as np
# np.random.seed(123)
# tails = [0]
# for x in range(10) :
#     coin = np.random.randint(0, 2)
#     tails.append(tails[x] + coin)
# ```
#
# ## 100 runs
# ```python
# import numpy as np
# np.random.seed(123)
# final_tails = []
# for x in range(100) :
#     tails = [0]
#     for x in range(10) :
#         coin = np.random.randint(0, 2)
#         tails.append(tails[x] + coin)
#     final_tails.append(tails[-1])
# print(final_tails)
# ```
#
# ## Histogram, 100 runs
#
# ```python
# import numpy as np
# np.random.seed(123)
# final_tails = []
# for x in range(100) :
#     tails = [0]
#     for x in range(10) :
#         coin = np.random.randint(0, 2)
#         tails.append(tails[x] + coin)
#     final_tails.append(tails[-1])
# plt.hist(final_tails, bins = 10)
# plt.show()
# ```
#
# ## Histogram, 1000 runs
#
# ```python
# import numpy as np
# np.random.seed(123)
# final_tails = []
# for x in range(1000) :
#     tails = [0]
#     for x in range(10) :
#         coin = np.random.randint(0, 2)
#         tails.append(tails[x] + coin)
#     final_tails.append(tails[-1])
# plt.hist(final_tails, bins = 10)
# plt.show()
# ```
#
#
#
# ## Histogram, 10000 runs
#
# ```python
# import numpy as np
# np.random.seed(123)
# final_tails = []
# for x in range(10000) :
#     tails = [0]
#     for x in range(10) :
#         coin = np.random.randint(0, 2)
#         tails.append(tails[x] + coin)
#     final_tails.append(tails[-1])
# plt.hist(final_tails, bins = 10)
# plt.show()
# ```

# %%
# Random Walk
import numpy as np
np.random.seed(123)
tails = [0]
for x in range(10) :    
    coin = np.random.randint(0, 2)    
    tails.append(tails[x] + coin)

# %%
# 100 runs
import numpy as np
np.random.seed(123)
final_tails = []
for x in range(100) :   
    tails = [0]
    for x in range(10) :        
        coin = np.random.randint(0, 2)        
        tails.append(tails[x] + coin)    
    final_tails.append(tails[-1])
print(final_tails)
# Out:
# [3, 6, 4, 5, 4, 5, 3, 5, 4, 6, 6, 8, 6, 4, 7, 5, 7, 4, 3, 3, 4, 5, 8, 5, 6, 5, 7, 6, 4, 5, 8, 5, 8, 4, 6, 6, 3, 4, 5, 4, 7, 8, 9, 4, 3, 4, 5, 6, 4, 2, 6, 6, 5, 7, 5, 4, 5, 5, 6, 7, 6, 6, 6, 3, 6, 3, 6, 5, 6, 5, 6, 4, 6, 6, 3, 4, 4, 2, 4, 5, 4, 6, 6, 6, 8, 4, 6, 5, 7, 4, 6, 5, 4, 6, 7, 3, 7, 4, 5, 7]

# %%
# Histogram, 100 runs

import numpy as np
np.random.seed(123)
final_tails = []
for x in range(100) :   
    tails = [0]
    for x in range(10) :        
        coin = np.random.randint(0, 2)        
        tails.append(tails[x] + coin)    
    final_tails.append(tails[-1])
plt.hist(final_tails, bins = 10)
plt.show()

# %%
## Histogram, 1000 runs

import numpy as np
np.random.seed(123)
final_tails = []
for x in range(1000) :   
    tails = [0]
    for x in range(10) :        
        coin = np.random.randint(0, 2)        
        tails.append(tails[x] + coin)    
    final_tails.append(tails[-1])
plt.hist(final_tails, bins = 10)
plt.show()

# %%
## Histogram, 10000 runs

import numpy as np
np.random.seed(123)
final_tails = []
for x in range(10000) :   
    tails = [0]
    for x in range(10) :        
        coin = np.random.randint(0, 2)        
        tails.append(tails[x] + coin)    
    final_tails.append(tails[-1])
plt.hist(final_tails, bins = 10)
plt.show()

# %% [markdown]
# ## Explore Datasets
# Use the DataFrames imported in the first cell to explore the data and practice your skills!
# - Create a loop that iterates through the `brics` DataFrame and prints "The population of {country} is {population} million!".
# - Create a histogram of the life expectancies for countries in Africa in the `gapminder` DataFrame. Make sure your plot has a title, axis labels, and has an appropriate number of bins.
# - Simulate 10 rolls of two six-sided dice. If the two dice add up to 7 or 11, print "A win!". If the two dice add up to 2, 3, or 12, print "A loss!". If the two dice add up to any other number, print "Roll again!".

# %%
## Exploring 'brics' dataFrame
print(brics.head())

for index, row in brics.iterrows():
    print(f"The population of {row['country']} is {row['population']:.2f} million!")
# Out:
#                  country    capital    area  population  name_length
# country_ab
# BR                Brazil   Brasilia   8.516      200.40            6
# RU                Russia     Moscow  17.100      143.50            6
# IN                 India  New Delhi   3.286     1252.00            5
# CH                 China    Beijing   9.597     1357.00            5
# SA          South Africa   Pretoria   1.221       52.98           12
# The population of Brazil is 200.40 million!
# The population of Russia is 143.50 million!
# The population of India is 1252.00 million!
# The population of China is 1357.00 million!
# The population of South Africa is 52.98 million!

# %%
print(gapminder.head())
import matplotlib.pyplot as plt
plt.hist(gapminder['life_exp'], bins=30)
plt.ylabel("Life Expectancies")
plt.title("Life Expectancies For Countries in Africa ")
# Out:
#        country  year  population      cont  life_exp       gdp_cap
# 0  Afghanistan  2007  31889923.0      Asia    43.828    974.580338
# 1      Albania  2007   3600523.0    Europe    76.423   5937.029526
# 2      Algeria  2007  33333216.0    Africa    72.301   6223.367465
# 3       Angola  2007  12420476.0    Africa    42.731   4797.231267
# 4    Argentina  2007  40301927.0  Americas    75.320  12779.379640
# Text(0.5, 1.0, 'Life Expectancies For Countries in Africa ')

# %%
import random
np.random.seed(123)
# simulate 10 rolls
for x in range(10):
    # roll 2 six-sided die
    Toss1 = np.random.randint(1,7)
    Toss2 = np.random.randint(1,7)
    sum = Toss1 + Toss2
    
    if sum in [7,11]:
        print("A win!")
    elif sum in [2,3,12]:
        print("A loss!")
    else :
        print("Roll again!")
# Out:
# Roll again!
# Roll again!
# Roll again!
# A win!
# Roll again!
# A loss!
# A loss!
# A loss!
# Roll again!
# Roll again!

# %%
import random
np.random.seed(123)
diceT = []
for x in range(10):
    dice1 = np.random.randint(1,6)
    dice2 = np.random.randint(1,6)
    diceT = dice1+dice2
    if diceT in [7,11]:
        print("A win!")
    elif diceT in [2,3,12]:
        print("A loss!")
    else :
        print("Roll again!")
# Out:
# Roll again!
# Roll again!
# A win!
# Roll again!
# A loss!
# Roll again!
# A loss!
# Roll again!
# Roll again!
# Roll again!
